# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')

if anthropic_api_key:
    print(f"OpenAI API Key exists and begins {anthropic_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-ant-a

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

openai = OpenAI(base_url=os.getenv('OLLAMA_BASE_URL'), api_key=os.getenv('OLLAMA_API_KEY'))

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(
    model="gemma4:31b-cloud",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 = 4

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(
    model="gemma4:31b-cloud",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# If all Zogs are Bleeps, and some Bleeps are Floops, but no Floops are Zogs, does it necessarily follow that some Bleeps are neither Zogs nor Floops?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = openai.chat.completions.create(
    model="qwen3.5:397b-cloud",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# No, it does **not** necessarily follow.
#
# Here is the breakdown using logic and a counter-example:
#
# **The Logic**
# 1.  **All Zogs are Bleeps:** The "Zog" circle is entirely inside the "Bleep" circle.
# 2.  **Some Bleeps are Floops:** The "Floop" circle overlaps with the "Bleep" circle.
# 3.  **No Floops are Zogs:** The "Floop" circle and the "Zog" circle do not touch.
#
# From these premises, we know there are Bleeps that are Zogs, and there are Bleeps that are Floops (which are definitely not Zogs). However, we do not know if there are any Bleeps left over. The set of Bleeps could be made up *entirely* of Zogs and Floops.
#
# **A Counter-Example**
# Imagine the following scenario:
# *   **Bleeps** = {Red Balls, Blue Balls}
# *   **Zogs** = {Red Balls}
# *   **Floops** = {Blue Balls}
#
# Let's check the premises:
# *   *All Zogs are Bleeps?* **Yes** (All Red Balls are in the group of Red and Blue Balls).
# *   *Some Bleeps are Floops?* **Yes** (The Blue Balls are Bleeps).
# *   *No Floops are Zogs?* **Yes** (No Blue Balls are Red Balls).
#
# Now check the conclusion:
# *   *Some Bleeps are neither Zogs nor Floops?* **No.** Every Bleep is either a Red Ball (Zog) or a Blue Ball (Floo). There are no Bleeps left over.
#
# Therefore, the conclusion is not guaranteed.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# No, it does **not** necessarily follow.
#
# Here is the breakdown using logic and a counter-example:
#
# **The Logic**
# 1.  **All Zogs are Bleeps:** The "Zog" circle is entirely inside the "Bleep" circle.
# 2.  **Some Bleeps are Floops:** The "Floop" circle overlaps with the "Bleep" circle.
# 3.  **No Floops are Zogs:** The "Floop" circle and the "Zog" circle do not touch.
#
# From these premises, we know there are Bleeps that are Zogs, and there are Bleeps that are Floops (which are definitely not Zogs). However, we do not know if there are any Bleeps left over. The set of Bleeps could be made up *entirely* of Zogs and Floops.
#
# **A Counter-Example**
# Imagine the following scenario:
# *   **Bleeps** = {Red Balls, Blue Balls}
# *   **Zogs** = {Red Balls}
# *   **Floops** = {Blue Balls}
#
# Let's check the premises:
# *   *All Zogs are Bleeps?* **Yes** (All Red Balls are in the group of Red and Blue Balls).
# *   *Some Bleeps are Floops?* **Yes** (The Blue Balls are Bleeps).
# *   *No Floops are Zogs?* **Yes** (No Blue Balls are Red Balls).
#
# Now check the conclusion:
# *   *Some Bleeps are neither Zogs nor Floops?* **No.** Every Bleep is either a Red Ball (Zog) or a Blue Ball (Floo). There are no Bleeps left over.
#
# Therefore, the conclusion is not guaranteed.

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "Name one business area that stands at the top when you think of potential use case of Agentic AI and its impact on society? (I just want you to name the business area, no explanation needed)"}]

# Then make the first call:

business_area = openai.chat.completions.create(
    model="gemma4:31b-cloud",
    messages=messages
).choices[0].message.content

print("Business area: ", business_area)

# And repeat! In the next message, include the business idea within the message

messages = [{"role": "user", "content": f"Name a pain point in {business_area} that might be ripe for an Agentic AI solution."}]

pain_point = openai.chat.completions.create(
    model="gemma4:31b-cloud",
    messages=messages
).choices[0].message.content

print("Pain point: ", pain_point)

# Then read the business idea:

messages = [{"role": "user", "content": f"Propose an Agentic AI solution for the following pain point in {business_area}: {pain_point}"}]

agentic_ai_solution = openai.chat.completions.create(
    model="qwen3.5:397b-cloud",
    messages=messages
).choices[0].message.content

# Then read the business idea:

print(agentic_ai_solution)
# Out:
# Business area:  Healthcare
# Pain point:  A significant pain point in healthcare ripe for Agentic AI is **Prior Authorization and Revenue Cycle Management (RCM).**
#
# ### The Pain Point: The "Administrative Deadlock"
# Currently, before a patient can receive a specific medication, surgery, or diagnostic test (like an MRI), the provider must get approval from the insurance company. This process is currently a manual, fragmented nightmare:
#
# 1.  **The Burden:** Nurses or medical assistants spend hours faxing documents, calling insurance portals, and manually uploading clinical notes to prove "medical necessity."
# 2.  **The Friction:** Insurance companies often reject requests due to missing documentation or "incorrect" coding, leading to a back-and-forth loop.
# 3.  **The Outcome:** Patient care is delayed (sometimes for weeks), provider burnout increases, and clinics lose revenue due to claim denials.
#
# ---
#
# ### Why this requires "Agentic" AI (not just Generative AI)
# A standard LLM (like a basic chatbot) can summarize a patient record, but it cannot solve prior authorization because this task requires **reasoning, tool-use, and autonomy.**
#
# An **Agentic AI solution** would operate as a "Digital Care Coordinator" with the following capabilities:
#
# **1. Autonomous Orchestration (The "Loop"):**
# Instead of just drafting a letter, the agent would:
# *   **Trigger:** Detect when a doctor orders a procedure in the EHR (Electronic Health Record).
# *   **Analyze:** Scan the patient's history to find the specific clinical markers required by that specific insurance provider’s policy.
# *   **Act:** Log into the insurance portal, upload the necessary documents, and submit the request.
#
# **2. Tool Use & Integration:**
# The agent would have "arms." It would integrate with:
# *   **EHRs (Epic/Cerner):** To pull the latest lab results.
# *   **Payer APIs:** To check the current coverage rules.
# *   **Communications tools:** To email the doctor if a specific piece of missing information (e.g., "Patient tried Physical Therapy for 6 weeks") is needed to secure approval.
#
# **3. Adaptive Problem Solving (Handling the "No"):**
# If the insurance company denies the request, a non-agentic AI would just report the denial. An **Agentic AI** would:
# *   Read the denial reason.
# *   Reason through the clinical notes to find a counter-argument.
# *   Automatically draft and submit an appeal based on the specific rejection code.
#
# ### The Value Proposition
# *   **For Patients:** Treatment starts in hours instead of weeks.
# *   **For Providers:** Massive reduction in administrative overhead and "pajama time" (doctors doing paperwork at night).
# *   **For Payers:** Reduction in manual review costs and standardized submission of evidence.
#
# ### The Guardrail (Human-in-the-Loop)
# Because this is healthcare, the agent wouldn't act in a vacuum. It would operate on a **"Human-in-the-Loop" (HITL)** model: the AI prepares the entire submission and the "argument" for medical necessity, and a human administrator simply clicks **"Approve and Send."**
# Here is a comprehensive proposal for an Agentic AI solution designed to resolve the Prior Authorization and Revenue Cycle Management deadlock.
#
# # Solution Name: ClearPath AuthAgent
# ### **Tagline:** Autonomous Preparation, Human Verification, Zero Friction.
#
# ---
#
# ## 1. Executive Summary
# **ClearPath AuthAgent** is a multi-agent orchestration system designed to automate the end-to-end Prior Authorization (PA) lifecycle. Unlike generative AI tools that merely draft text, ClearPath acts as a **digital employee**. It observes EHR triggers, queries payer policies, gathers clinical evidence, navigates payer portals, and manages denials. It operates under a **"Human-in-the-Loop" (HITL)** governance model, ensuring that while the *work* is autonomous, the *liability* remains with the provider.
#
# ---
#
# ## 2. System Architecture: The Multi-Agent Swarm
# To handle the complexity of healthcare RCM, a single model is insufficient. ClearPath utilizes a **Swarm Architecture** where specialized agents collaborate under a central Orchestrator.
#
# | Agent Role | Responsibility | Tools Used |
# | :--- | :--- | :--- |
# | **🕵️ The Sentinel (Intake)** | Monitors EHR for new orders requiring PA. Identifies CPT/HCPCS codes. | EHR API (FHIR), Order Entry System |
# | **⚖️ The Policy Analyst** | Retrieves specific medical coverage policies for the patient's payer/plan. | Payer APIs, Policy Knowledge Base (RAG) |
# | **📂 The Evidence Gatherer** | Scans patient history for required clinical markers (e.g., failed conservative therapy). | EHR Database, Document Store, Lab Systems |
# | **✍️ The Scribe** | Drafts the Letter of Medical Necessity (LMN) and populates forms. | LLM (Clinical Fine-Tuned), Form Filler |
# | **🤝 The Liaison** | Submits data to payer portals and tracks status. | RPA (Browser Automation), Payer APIs |
# | **🛡️ The Advocate** | Detects denials, analyzes reason codes, and drafts appeals. | Denial Code Database, Appeal Logic Engine |
#
# ---
#
# ## 3. The Agentic Workflow (The "Loop")
#
# ### Phase 1: Trigger & Triage (Autonomous)
# 1.  **Trigger:** A physician orders an MRI (CPT 72148) in Epic/Cerner.
# 2.  **Detection:** **The Sentinel** detects the order and flags it as "PA Required" based on the patient's insurance metadata.
# 3.  **Policy Lookup:** **The Policy Analyst** queries the payer's specific policy (e.g., "Aetna Policy #MRI-2024"). It identifies that approval requires proof of "6 weeks of physical therapy" and "neurological exam."
#
# ### Phase 2: Evidence Gathering & Gap Analysis (Autonomous)
# 1.  **Search:** **The Evidence Gatherer** scans the patient's chart for PT referrals and neuro notes from the last 90 days.
# 2.  **Gap Detection:** The Agent finds PT referrals but no completion notes.
# 3.  **Intervention:** Instead of failing, the Agent sends a secure message to the Care Coordinator: *"Missing PT completion notes for Patient X. Please upload or confirm exemption."*
# 4.  **Resolution:** Once the human uploads the note, the Agent resumes.
#
# ### Phase 3: Drafting & Submission (HITL)
# 1.  **Assembly:** **The Scribe** compiles the clinical notes, lab results, and policy references into a structured JSON payload or PDF.
# 2.  **Drafting:** It generates the Letter of Medical Necessity, explicitly citing the policy clauses that justify the request.
# 3.  **Human Verification:** The Care Coordinator receives a notification: *"PA Request Ready for Review."* They view the compiled evidence and the drafted argument.
# 4.  **Action:** The human clicks **"Approve and Send."**
# 5.  **Execution:** **The Liaison** logs into the payer portal (via secure RPA or API) and submits the package.
#
# ### Phase 4: Adaptive Problem Solving (The "Denial Loop")
# 1.  **Status Check:** The Agent polls the payer status daily.
# 2.  **Denial Detected:** Payer returns Status: **Denied**. Reason: *"Code 50 - Non-covered service without prior conservative management."*
# 3.  **Reasoning:** **The Advocate** analyzes the denial. It cross-references the submitted data and realizes the PT note was dated 3 years ago, not 6 weeks ago.
# 4.  **Strategy:** The Agent identifies a different policy clause regarding "Acute Neurological Deficit" which waives the PT requirement.
# 5.  **Appeal Prep:** It drafts an appeal letter highlighting the acute neurological findings in the initial exam.
# 6.  **HITL:** It alerts the human: *"Denial Detected. Counter-argument prepared based on Acute Deficit clause. Review for Appeal?"*
#
# ---
#
# ## 4. Technical Enablers & Integration
#
# ### A. Connectivity (The "Arms")
# *   **FHIR/HL7 Interfaces:** Bi-directional sync with major EHRs (Epic, Cerner, Meditech) to read orders and write status updates.
# *   **Payer API Network:** Integration with networks like **Change Healthcare** or **Availity** where APIs exist.
# *   **Secure RPA:** For payers without APIs, the Agent uses headless browser automation (e.g., Selenium/Puppeteer) within a secure enclave to navigate web portals, mimicking human clicks but logging every action.
#
# ### B. Intelligence (The "Brain")
# *   **RAG (Retrieval-Augmented Generation):** The Policy Analyst does not rely on model training data. It retrieves live PDF policies from payer websites to ensure the rules are current.
# *   **Chain-of-Thought Reasoning:** The Agent must output its reasoning trace (e.g., *"I am selecting this note because it contains the keyword 'radiculopathy' required by Policy Section 4.2"*) for auditability.
#
# ### C. Security & Compliance (The "Shield")
# *   **HIPAA Compliance:** All data encrypted at rest and in transit. No PHI used for model training.
# *   **Audit Trails:** Every action taken by the Agent (query, draft, submit) is immutably logged.
# *   **Role-Based Access:** The Agent operates with the minimum necessary privilege level required to submit claims.
#
# ---
#
# ## 5. Implementation Roadmap
#
# | Phase | Focus | Outcome |
# | :--- | :--- | :--- |
# | **1. Pilot** | Single Specialty (e.g., Orthopedics), Single Payer. | Validate accuracy of policy retrieval and evidence gathering. |
# | **2. Integration** | Deep EHR Integration (Write-back capabilities). | Agent updates EHR status fields automatically; reduces double entry. |
# | **3. Expansion** | Multi-payer, Multi-specialty, Appeals Automation. | Full RCM coverage including denial management. |
# | **4. Optimization** | Predictive Analytics. | Agent predicts likelihood of denial *before* submission and suggests order adjustments to the doctor. |
#
# ---
#
# ## 6. Value Measurement (KPIs)
#
# To prove success, ClearPath tracks the following metrics:
#
# 1.  **Turnaround Time (TAT):** Target reduction from **14 days to <48 hours**.
# 2.  **First-Pass Yield:** Increase approval rate on first submission from ~60% to **>90%**.
# 3.  **Staff Hours Saved:** Measure reduction in FTE hours spent on faxing/calling. Target: **15 hours/week per provider**.
# 4.  **Denial Recovery Rate:** Percentage of initially denied claims successfully overturned by **The Advocate** agent.
#
# ---
#
# ## 7. Risk Mitigation: Why This Won't Fail
#
# | Risk | Mitigation Strategy |
# | :--- | :--- |
# | **Hallucination** (AI inventing clinical facts) | **Grounding:** The Agent is restricted to *extracting* data from the EHR, not generating clinical facts. It cannot invent lab results. |
# | **Payer Policy Changes** | **Continuous Monitoring:** The Policy Agent re-scrapes payer policy URLs weekly. If a policy hash changes, it flags the Orchestrator to pause submissions for that payer until verified. |
# | **Liability** | **HITL Gate:** The "Submit" button is always human-pressed. The AI is a "co-pilot," not the "pilot." The audit log proves the human reviewed the AI's work. |
# | **Integration Fatigue** | **Overlay UI:** Instead of forcing IT to build new screens, the Agent operates via a sidebar overlay within the existing EHR interface. |
#
# ## 8. Conclusion
# **ClearPath AuthAgent** moves healthcare administration from a **reactive, manual process** to a **proactive, autonomous workflow**. By leveraging Agentic AI, we do not just speed up the typing; we eliminate the friction of the "Administrative Deadlock." The result is a system where doctors practice medicine, administrators manage exceptions, and patients receive care without bureaucratic delay.

# %%
display(Markdown(agentic_ai_solution))
# Out:
# Here is a comprehensive proposal for an Agentic AI solution designed to resolve the Prior Authorization and Revenue Cycle Management deadlock.
#
# # Solution Name: ClearPath AuthAgent
# ### **Tagline:** Autonomous Preparation, Human Verification, Zero Friction.
#
# ---
#
# ## 1. Executive Summary
# **ClearPath AuthAgent** is a multi-agent orchestration system designed to automate the end-to-end Prior Authorization (PA) lifecycle. Unlike generative AI tools that merely draft text, ClearPath acts as a **digital employee**. It observes EHR triggers, queries payer policies, gathers clinical evidence, navigates payer portals, and manages denials. It operates under a **"Human-in-the-Loop" (HITL)** governance model, ensuring that while the *work* is autonomous, the *liability* remains with the provider.
#
# ---
#
# ## 2. System Architecture: The Multi-Agent Swarm
# To handle the complexity of healthcare RCM, a single model is insufficient. ClearPath utilizes a **Swarm Architecture** where specialized agents collaborate under a central Orchestrator.
#
# | Agent Role | Responsibility | Tools Used |
# | :--- | :--- | :--- |
# | **🕵️ The Sentinel (Intake)** | Monitors EHR for new orders requiring PA. Identifies CPT/HCPCS codes. | EHR API (FHIR), Order Entry System |
# | **⚖️ The Policy Analyst** | Retrieves specific medical coverage policies for the patient's payer/plan. | Payer APIs, Policy Knowledge Base (RAG) |
# | **📂 The Evidence Gatherer** | Scans patient history for required clinical markers (e.g., failed conservative therapy). | EHR Database, Document Store, Lab Systems |
# | **✍️ The Scribe** | Drafts the Letter of Medical Necessity (LMN) and populates forms. | LLM (Clinical Fine-Tuned), Form Filler |
# | **🤝 The Liaison** | Submits data to payer portals and tracks status. | RPA (Browser Automation), Payer APIs |
# | **🛡️ The Advocate** | Detects denials, analyzes reason codes, and drafts appeals. | Denial Code Database, Appeal Logic Engine |
#
# ---
#
# ## 3. The Agentic Workflow (The "Loop")
#
# ### Phase 1: Trigger & Triage (Autonomous)
# 1.  **Trigger:** A physician orders an MRI (CPT 72148) in Epic/Cerner.
# 2.  **Detection:** **The Sentinel** detects the order and flags it as "PA Required" based on the patient's insurance metadata.
# 3.  **Policy Lookup:** **The Policy Analyst** queries the payer's specific policy (e.g., "Aetna Policy #MRI-2024"). It identifies that approval requires proof of "6 weeks of physical therapy" and "neurological exam."
#
# ### Phase 2: Evidence Gathering & Gap Analysis (Autonomous)
# 1.  **Search:** **The Evidence Gatherer** scans the patient's chart for PT referrals and neuro notes from the last 90 days.
# 2.  **Gap Detection:** The Agent finds PT referrals but no completion notes.
# 3.  **Intervention:** Instead of failing, the Agent sends a secure message to the Care Coordinator: *"Missing PT completion notes for Patient X. Please upload or confirm exemption."*
# 4.  **Resolution:** Once the human uploads the note, the Agent resumes.
#
# ### Phase 3: Drafting & Submission (HITL)
# 1.  **Assembly:** **The Scribe** compiles the clinical notes, lab results, and policy references into a structured JSON payload or PDF.
# 2.  **Drafting:** It generates the Letter of Medical Necessity, explicitly citing the policy clauses that justify the request.
# 3.  **Human Verification:** The Care Coordinator receives a notification: *"PA Request Ready for Review."* They view the compiled evidence and the drafted argument.
# 4.  **Action:** The human clicks **"Approve and Send."**
# 5.  **Execution:** **The Liaison** logs into the payer portal (via secure RPA or API) and submits the package.
#
# ### Phase 4: Adaptive Problem Solving (The "Denial Loop")
# 1.  **Status Check:** The Agent polls the payer status daily.
# 2.  **Denial Detected:** Payer returns Status: **Denied**. Reason: *"Code 50 - Non-covered service without prior conservative management."*
# 3.  **Reasoning:** **The Advocate** analyzes the denial. It cross-references the submitted data and realizes the PT note was dated 3 years ago, not 6 weeks ago.
# 4.  **Strategy:** The Agent identifies a different policy clause regarding "Acute Neurological Deficit" which waives the PT requirement.
# 5.  **Appeal Prep:** It drafts an appeal letter highlighting the acute neurological findings in the initial exam.
# 6.  **HITL:** It alerts the human: *"Denial Detected. Counter-argument prepared based on Acute Deficit clause. Review for Appeal?"*
#
# ---
#
# ## 4. Technical Enablers & Integration
#
# ### A. Connectivity (The "Arms")
# *   **FHIR/HL7 Interfaces:** Bi-directional sync with major EHRs (Epic, Cerner, Meditech) to read orders and write status updates.
# *   **Payer API Network:** Integration with networks like **Change Healthcare** or **Availity** where APIs exist.
# *   **Secure RPA:** For payers without APIs, the Agent uses headless browser automation (e.g., Selenium/Puppeteer) within a secure enclave to navigate web portals, mimicking human clicks but logging every action.
#
# ### B. Intelligence (The "Brain")
# *   **RAG (Retrieval-Augmented Generation):** The Policy Analyst does not rely on model training data. It retrieves live PDF policies from payer websites to ensure the rules are current.
# *   **Chain-of-Thought Reasoning:** The Agent must output its reasoning trace (e.g., *"I am selecting this note because it contains the keyword 'radiculopathy' required by Policy Section 4.2"*) for auditability.
#
# ### C. Security & Compliance (The "Shield")
# *   **HIPAA Compliance:** All data encrypted at rest and in transit. No PHI used for model training.
# *   **Audit Trails:** Every action taken by the Agent (query, draft, submit) is immutably logged.
# *   **Role-Based Access:** The Agent operates with the minimum necessary privilege level required to submit claims.
#
# ---
#
# ## 5. Implementation Roadmap
#
# | Phase | Focus | Outcome |
# | :--- | :--- | :--- |
# | **1. Pilot** | Single Specialty (e.g., Orthopedics), Single Payer. | Validate accuracy of policy retrieval and evidence gathering. |
# | **2. Integration** | Deep EHR Integration (Write-back capabilities). | Agent updates EHR status fields automatically; reduces double entry. |
# | **3. Expansion** | Multi-payer, Multi-specialty, Appeals Automation. | Full RCM coverage including denial management. |
# | **4. Optimization** | Predictive Analytics. | Agent predicts likelihood of denial *before* submission and suggests order adjustments to the doctor. |
#
# ---
#
# ## 6. Value Measurement (KPIs)
#
# To prove success, ClearPath tracks the following metrics:
#
# 1.  **Turnaround Time (TAT):** Target reduction from **14 days to <48 hours**.
# 2.  **First-Pass Yield:** Increase approval rate on first submission from ~60% to **>90%**.
# 3.  **Staff Hours Saved:** Measure reduction in FTE hours spent on faxing/calling. Target: **15 hours/week per provider**.
# 4.  **Denial Recovery Rate:** Percentage of initially denied claims successfully overturned by **The Advocate** agent.
#
# ---
#
# ## 7. Risk Mitigation: Why This Won't Fail
#
# | Risk | Mitigation Strategy |
# | :--- | :--- |
# | **Hallucination** (AI inventing clinical facts) | **Grounding:** The Agent is restricted to *extracting* data from the EHR, not generating clinical facts. It cannot invent lab results. |
# | **Payer Policy Changes** | **Continuous Monitoring:** The Policy Agent re-scrapes payer policy URLs weekly. If a policy hash changes, it flags the Orchestrator to pause submissions for that payer until verified. |
# | **Liability** | **HITL Gate:** The "Submit" button is always human-pressed. The AI is a "co-pilot," not the "pilot." The audit log proves the human reviewed the AI's work. |
# | **Integration Fatigue** | **Overlay UI:** Instead of forcing IT to build new screens, the Agent operates via a sidebar overlay within the existing EHR interface. |
#
# ## 8. Conclusion
# **ClearPath AuthAgent** moves healthcare administration from a **reactive, manual process** to a **proactive, autonomous workflow**. By leveraging Agentic AI, we do not just speed up the typing; we eliminate the friction of the "Administrative Deadlock." The result is a system where doctors practice medicine, administrators manage exceptions, and patients receive care without bureaucratic delay.
